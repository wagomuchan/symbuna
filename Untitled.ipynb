# %%
import symbuna

# %%
    expr1 = symbuna.parse("2x + 3x")
    print("入力: 2x + 3x")
    print(f"出力 (LaTeX形式): {expr1}")
    print("-" * 30)
# Out:
# 入力: 2x + 3x
# 出力 (LaTeX形式): 2x + 3x
# ------------------------------

# %%
expr2 = symbuna.parse("5sin(x) + 2cos(x ^ 2)")

# %%
print(f"{expr2}")
# Out:
# 5\sin\left(x\right) + 2\cos\left(x^{2}\right)

# %%
expr2
# Out:
# $$5\sin\left(x\right) + 2\cos\left(x^{2}\right)$$

# %%
expr3 = symbuna.parse("sqrt((x - sqrt(3)) ^ 2 + y ^ 2) + sqrt((x + sqrt(3)) ^2 + y^2) ")

# %%
expr3
# Out:
# $$\sqrt{\left(x - \sqrt{3}\right)^{2} + y^{2}} + \sqrt{\left(x + \sqrt{3}\right)^{2} + y^{2}}$$

# %%
expr4 = symbuna.parse("(sin(x) + cos(x) ) ^ 2")

# %%
expr4
# Out:
# $$\left(\sin\left(x\right) + \cos\left(x\right)\right)^{2}$$

# %%
expr5 = symbuna.parse("(3x ^ 2 + 2x + 1) ^2")

# %%
expr5
# Out:
# $$\left(3x^{2} + 2x + 1\right)^{2}$$
